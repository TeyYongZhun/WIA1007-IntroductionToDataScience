# %%
# Source - https://stackoverflow.com/a
# Posted by tanemaki, modified by community. See post 'Timeline' for change history
# Retrieved 2025-11-12, License - CC BY-SA 4.0

import pandas as pd
import numpy as np
from scipy import stats

df = pd.DataFrame(np.random.randn(100, 3))

df[(np.abs(stats.zscore(df)) < 3).all(axis=1)]
# Out:
#            0         1         2
# 0  -0.347136 -0.032560  0.576335
# 1   0.825196  1.769490  0.806830
# 2  -0.190647 -0.732876 -0.036209
# 3   0.369166 -1.153917 -0.315202
# 4  -0.168685 -0.568480  0.227506
# ..       ...       ...       ...
# 95 -1.101404 -0.034773  0.083594
# 96 -0.118849  0.001726  1.281469
# 97  0.858716  2.395862 -0.699033
# 98 -0.815530 -0.567636 -2.439730
# 99  0.204132 -0.376842 -1.086736
#
# [99 rows x 3 columns]

# %%
import pandas as pd
import numpy as np
from scipy import stats

# Step 1: Create a simple dataframe with obvious outliers
data = {
    'Score': [85, 90, 78, 92, 88, 200, 85, 89, -50, 87]
}
df = pd.DataFrame(data)

print("ORIGINAL DATA:")
print(df)

# Step 2: Remove outliers using Z-score method
df_clean = df[(np.abs(stats.zscore(df)) < 2).all(axis=1)]

print("\nCLEANED DATA (outliers removed):")
print(df_clean)

# Step 3: Show what happened
print(f"\nSUMMARY:")
print(f"Original rows: {len(df)}")
print(f"Rows after cleaning: {len(df_clean)}")
print(f"Outliers removed: {len(df) - len(df_clean)}")

# Show which rows were removed as outliers
outliers = df[~df.index.isin(df_clean.index)]
print(f"Outliers: {outliers['Score'].values}")
# Out:
# ORIGINAL DATA:
#    Score
# 0     85
# 1     90
# 2     78
# 3     92
# 4     88
# 5    200
# 6     85
# 7     89
# 8    -50
# 9     87
#
# CLEANED DATA (outliers removed):
#    Score
# 0     85
# 1     90
# 2     78
# 3     92
# 4     88
# 6     85
# 7     89
# 9     87
#
# SUMMARY:
# Original rows: 10
# Rows after cleaning: 8
# Outliers removed: 2
# Outliers: [200 -50]
